# %% [markdown]
# #**Capstone Project - Analysis of Rio de Janeiro's Centro venues**

# %% [markdown]
# ## Table of contents
# * [Introduction](#introduction)
# * [Importing libraries and initial data gathering](#initial)
# * [Collecting, processing and starting to visualize data](#collecting)
# * [Using Silhouete and Elbow to find the best k](#metrics)
# * [Clean visuals for our clusters & final mapping](#visuals)
# * [What can we understand from the data?](#conclusion)

# %% [markdown]
# ##**1 - Introduction**<a name="introduction"></a>

# %% [markdown]
# In this project I will be using the Foursquare API to explore and analyse different venues on Rio de Janeiro's Centro, a neighborhood known as the heart of business in the city, also home of some of the most important Museums and restaurants in the city. The idea is to provide information that could help a tourist vising the city to choose the best hotel to stay, based on the locations they decide to visit within walking distance and other preferences.

# %% [markdown]
# ##**2 - Importing libraries and initial data gathering**<a name="initial"></a>

# %% [markdown]
# here are some of the most important python libraries used on this project:

# %%
import requests
import pandas as pd
import numpy as np
import random
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

#!pip install geopy # remove the comment to install if necessary
from geopy.geocoders import Nominatim

from IPython.display import Image 
from IPython.core.display import HTML 
    
from pandas.io.json import json_normalize

#! pip install folium==0.5.0 # remove the comment to install if necessary
import folium

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# Foursquare API requests 3 different user keys when making calls to their database, the Client ID, the Client Secret and the Access Token. Those are all listed below, and since its also required for us to provide the version of the API we are trying to access, it will be listed here aswell, together with a initial queries Limit value.

# %%
CLIENT_ID = '#my Foursquare ID'
CLIENT_SECRET = '#my Foursquare Secret' 
ACCESS_TOKEN = '#my FourSquare Access Token' 
VERSION = 20180604
LIMIT = 30
print('Your credentials:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentials:
# CLIENT_ID: 1QQCADPYRVDCFII0L3TQQKJNHDCHTXETVHHAHLQ3VEXZI1HQ
# CLIENT_SECRET:B1KIFVQLWSRCUY2OLRZBHCQWOSATB2O41L2NQGUNX3INJE54

# %% [markdown]
# Here we are using the geolocator to provide coordinates used as starting point for data collection. Santos Dumont Airport was chosen for its tourist traffic and we'll expand from there.

# %%
address = 'Aeroporto Santos Dumont, Centro, Rio de Janeiro, RJ'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# -22.91071875 -43.164178244974906

# %% [markdown]
# Here we're choosing 'Hotel' as our search query, which will return all hotels on a 8km radius from the airport. After the data preparation, we'll plot on a map using Folium to see if we can use them as base our data analysis.

# %%
search_query = 'Hotel'
radius = 8000

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)

results = requests.get(url).json()

hoteis = results['response']['venues']
df_venues = json_normalize(hoteis)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead

# %% [markdown]
# As you can see below, the data was sucessfully pulled, transformed into a dataframe using pandas, but it's full of unnecessary information for our current objective:

# %%
df_venues.head()
# Out:
#                          id  ... location.crossStreet
# 0  58bdfa760e0a1e57cf5b2154  ...                  NaN
# 1  4baa6677f964a5208e663ae3  ...                  NaN
# 2  4b058720f964a520ef8022e3  ...                  NaN
# 3  4d88150f5ecdf04d42cf8f8a  ...                  NaN
# 4  5912388e9de23b2ae27a53db  ...                  NaN
#
# [5 rows x 17 columns]

# %% [markdown]
# Let's clean this dataframe a bit by creating a new one with only the useful columns, rename them and and proceed exploring our data:

# %%
df_hoteis = pd.DataFrame([df_venues['name'],df_venues['location.lat'],df_venues['location.lng'],df_venues['location.distance']])
df_hoteis = df_hoteis.transpose()
df_hoteis['category']='Hotel'
df_hoteis.rename(columns={'location.lat':'latitude','location.lng':'longitude','location.distance':'distance'}, inplace=True)

# %%
print(df_hoteis.info())
print(df_hoteis.shape)
df_hoteis.head(30)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   name       30 non-null     object
#  1   latitude   30 non-null     object
#  2   longitude  30 non-null     object
#  3   distance   30 non-null     object
#  4   category   30 non-null     object
# dtypes: object(5)
# memory usage: 1.3+ KB
# None
# (30, 5)
#                            name latitude longitude distance category
# 0         Rooftop Prodigy Hotel -22.9142  -43.1672      489    Hotel
# 1                    ibis Hotel -22.9085  -43.1695      598    Hotel
# 2         Hotel Aeroporto Othon -22.9108  -43.1711      708    Hotel
# 3      Hotel Atlântico Business -22.9114  -43.1767     1286    Hotel
# 4              Hotel Demoiselle -22.9052  -43.1681      739    Hotel
# 5         Hotel Atlântico Tower -22.9003  -43.1799     1988    Hotel
# 6            Hotel Santa Teresa -22.9216  -43.1875     2684    Hotel
# 7              Hotel Novo Mundo -22.9255  -43.1731     1879    Hotel
# 8                 Itajubá Hotel -22.9114  -43.1762     1231    Hotel
# 9             Golden Park Hotel -22.9219  -43.1741     1605    Hotel
# 10              Hotel Americano -22.9159  -43.1789     1611    Hotel
# 11              Hotel Vila Rica -22.9161  -43.1782     1554    Hotel
# 12       Windsor Asturias Hotel -22.9117  -43.1765     1273    Hotel
# 13       Hotel Américas Granada -22.9116  -43.1836     1995    Hotel
# 14      Windsor Guanabara Hotel -22.9012  -43.1796     1900    Hotel
# 15        Hotel Flamengo Palace -22.9248  -43.1732     1819    Hotel
# 16          Hotel Monte Castelo -22.9199  -43.1789     1828    Hotel
# 17                Hotel challon -22.9207  -43.1816     2108    Hotel
# 18  Prodigy Hotel Santos Dumont -22.9147  -43.1665      505    Hotel
# 19        Windsor Flórida Hotel -22.9269  -43.1764     2197    Hotel
# 20                 Hotel Regina -22.9275  -43.1747     2154    Hotel
# 21                   ibis Hotel -22.9074  -43.1819     1855    Hotel
# 22                   Hotel Leão -22.9272  -43.1787     2363    Hotel
# 23              Hotel Argentina -22.9368  -43.1752     3115    Hotel
# 24           Hotel Monte Alegre -22.9151  -43.1875     2437    Hotel
# 25            ibis Budget Hotel -22.9073  -43.1819     1855    Hotel
# 26           Mengo Palace Hotel -22.9285  -43.1752     2283    Hotel
# 27             Fluminense Hotel -22.9129  -43.1847     2119    Hotel
# 28              HOTEL Champagne -22.9112   -43.191     2752    Hotel
# 29                 Center Hotel  -22.899    -43.18     2079    Hotel

# %% [markdown]
# ##**3 - Collecting, Processing and starting to visualize data**<a name="collecting"></a>

# %% [markdown]
# We've done our initial data cleanup, so I think we are ready to start visualizing our starting point on the airport and nearby hotels:

# %%
airport_lat = -22.91071875
airport_lon = -43.164178244974906

map_centro = folium.Map(location=[airport_lat, airport_lon],zoom_start=15)

folium.CircleMarker(
                    [airport_lat, airport_lon],
                    radius=10,
                    popup='Santos Dumont Airport',
                    fill=True,
                    color='red',
                    fill_color='red',
                    fill_opacity=0.6).add_to(map_centro)
map_centro
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_4824fb6e1f9e413d86ec603d2c5e74a4%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_4824fb6e1f9e413d86ec603d2c5e74a4%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_4824fb6e1f9e413d86ec603d2c5e74a4%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_4824fb6e1f9e413d86ec603d2c5e74a4%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B-22.91071875%2C%20-43.164178244974906%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2015%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_7c8bb2fbf0944340b348979ccd13cdce%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20 ...

# %%
map_centro_hoteis = folium.Map(location=[airport_lat, airport_lon],zoom_start=15)

for lat, lon, name in zip(df_hoteis['latitude'],df_hoteis['longitude'],df_hoteis['name']):
    label = '{}'.format(name)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        fill=True,
        color='blue',
        fill_color='yellow',
        fill_opacity=0.5
        ).add_to(map_centro_hoteis)

map_centro_hoteis
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_d2f027e25acb45c2b164d54c0666d665%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_d2f027e25acb45c2b164d54c0666d665%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_d2f027e25acb45c2b164d54c0666d665%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_d2f027e25acb45c2b164d54c0666d665%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B-22.91071875%2C%20-43.164178244974906%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2015%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_0d560e87b4da4c6688ff81d5fa0c34c9%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20 ...

# %% [markdown]
# ### **3.1 - Collecting venues data**
#
# Looks like the initial data is plotting correctly, so we can move on and start getting more interesting data from Foursquare API, like restaurants, bars and museums. We can repeat the search, data gathering and cleanup we did for our hotels with other venues:

# %% [markdown]
# Collecting restaurants and food venues data and adding related category column:

# %%
search_query = 'food'
limit_places = 100

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, search_query, radius, limit_places)
results = requests.get(url).json()

food = results['response']['venues']
df_food = json_normalize(food)

df_food['category']='Food'
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """

# %%
print(df_food.info())
print(df_food.shape)
df_food.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         50 non-null     object
#  1   name                       50 non-null     object
#  2   categories                 50 non-null     object
#  3   referralId                 50 non-null     object
#  4   hasPerk                    50 non-null     bool
#  5   location.address           29 non-null     object
#  6   location.lat               50 non-null     float64
#  7   location.lng               50 non-null     float64
#  8   location.labeledLatLngs    50 non-null     object
#  9   location.distance          50 non-null     int64
#  10  location.postalCode        18 non-null     object
#  11  location.cc                50 non-null     object
#  12  location.city              36 non-null     object
#  13  location.state             37 non-null     object
#  14  location.country           50 non-null     object
#  15  location.formattedAddress  37 non-null     object
#  16  location.crossStreet       7 non-null      object
#  17  category                   50 non-null     object
# dtypes: bool(1), float64(2), int64(1), object(14)
# memory usage: 6.8+ KB
# None
# (50, 18)
#                          id  ... category
# 0  57e59302498e6a859d6dd2df  ...     Food
# 1  56427127498e4309fc73811e  ...     Food
# 2  5e5bf05498c49900087f5703  ...     Food
# 3  5f5f6c9624ae6f671d9fe64b  ...     Food
# 4  55d34ae5498e9a38dae27fb8  ...     Food
#
# [5 rows x 18 columns]

# %% [markdown]
# Collecting Coffee shops data and adding related category column:

# %%
search_query = 'coffee'
limit_places = 100

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, search_query, radius, limit_places)

results = requests.get(url).json()

coffee = results['response']['venues']
df_coffee = json_normalize(coffee)

df_coffee['category'] ='Coffee'
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead

# %%
print(df_coffee.info())
print(df_coffee.shape)
df_coffee.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         50 non-null     object
#  1   name                       50 non-null     object
#  2   categories                 50 non-null     object
#  3   referralId                 50 non-null     object
#  4   hasPerk                    50 non-null     bool
#  5   location.address           41 non-null     object
#  6   location.crossStreet       12 non-null     object
#  7   location.lat               50 non-null     float64
#  8   location.lng               50 non-null     float64
#  9   location.labeledLatLngs    50 non-null     object
#  10  location.distance          50 non-null     int64
#  11  location.postalCode        28 non-null     object
#  12  location.cc                50 non-null     object
#  13  location.city              40 non-null     object
#  14  location.state             40 non-null     object
#  15  location.country           50 non-null     object
#  16  location.formattedAddress  42 non-null     object
#  17  location.neighborhood      2 non-null      object
#  18  category                   50 non-null     object
# dtypes: bool(1), float64(2), int64(1), object(15)
# memory usage: 7.2+ KB
# None
# (50, 19)
#                          id                 name  ... location.neighborhood category
# 0  5820a476afe10172680d5392  Gastrô Coffee Break  ...                   NaN   Coffee
# 1  56a48b6a498e29423d33fa46               Coffee  ...                   NaN   Coffee
# 2  5ab0598b4928141356fed631          Coffee Five  ...                   NaN   Coffee
# 3  4bcb4834fb84c9b64e7e1e3e    Califórnia Coffee  ...   Centro, Niterói, RJ   Coffee
# 4  50880434e4b05e0a9439896a   Brasas Coffee Shop  ...                   NaN   Coffee
#
# [5 rows x 19 columns]

# %% [markdown]
# Collecting Bars and drinks venues data and adding related category column:

# %%
search_query = 'bar'
limit_places = 100
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, search_query, radius, limit_places)

results = requests.get(url).json()

drinks = results['response']['venues']
df_drinks = json_normalize(drinks)

df_drinks['category'] = 'Drinks'
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead

# %%
print(df_drinks.info())
print(df_drinks.shape)
df_drinks.head(100)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         50 non-null     object
#  1   name                       50 non-null     object
#  2   categories                 50 non-null     object
#  3   referralId                 50 non-null     object
#  4   hasPerk                    50 non-null     bool
#  5   location.address           44 non-null     object
#  6   location.crossStreet       13 non-null     object
#  7   location.lat               50 non-null     float64
#  8   location.lng               50 non-null     float64
#  9   location.labeledLatLngs    50 non-null     object
#  10  location.distance          50 non-null     int64
#  11  location.postalCode        33 non-null     object
#  12  location.cc                50 non-null     object
#  13  location.city              49 non-null     object
#  14  location.state             49 non-null     object
#  15  location.country           50 non-null     object
#  16  location.formattedAddress  49 non-null     object
#  17  location.neighborhood      1 non-null      object
#  18  venuePage.id               2 non-null      object
#  19  category                   50 non-null     object
# dtypes: bool(1), float64(2), int64(1), object(16)
# memory usage: 7.6+ KB
# None
# (50, 20)
#                           id  ... category
# 0   4cc9a7b3bcb1b1f7bc94108a  ...   Drinks
# 1   4fa3e161e4b09d4d446293c5  ...   Drinks
# 2   4c6ef4a4d274b60c8820d50d  ...   Drinks
# 3   503253b5e4b01a4fc2f1043e  ...   Drinks
# 4   4bc49383b492d13a9c33aa60  ...   Drinks
# 5   4e4e7d12fa7626401e9b7e7a  ...   Drinks
# 6   4d99efae97d06ea8ff17550b  ...   Drinks
# 7   4df9274862e1e9a243662715  ...   Drinks
# 8   4bd5ad964e32d13a8435c180  ...   Drinks
# 9   4cd363e9a61c4688ce6ab328  ...   Drinks
# 10  4e9852f9d3e322c8a1c120a5  ...   Drinks
# 11  57f5345d498e675a1e6e8b04  ...   Drinks
# 12  4d262c1ca813224b85aaefb1  ...   Drinks
# 13  4bd612e76f649521e94170ec  ...   Drinks
# 14  5b8131a0aa6c95002c1def8a  ...   Drinks
# 15  4e5074ce2271a1bdc3ee3232  ...   Drinks
# 16  4e3c5e0baeb73139a16aaa2c  ...   Drinks
# 17  4de3ce6445dd180ae566793a  ...   Drinks
# 18  4c119d84d917c9285822b662  ...   Drinks
# 19  4b07da1df964a520770023e3  ...   Drinks
# 20  4e61055bc65b2dc89effaea8  ...   Drinks
# 21  4d309ca1f9daa1cd6eea6750  ...   Drinks
# 22  4d5febfbef378cfac43a76a6  ...   Drinks
# 23  5081996be4b0ec60c48b1994  ...   Drinks
# 24  4fb0e247e4b01cbf31017dd0  ...   Drinks
# 25  4ff62943e4b0b8fda9a15f7f  ...   Drinks
# 26  51465dbce4b0da66e787a53f  ...   Drinks
# 27  4c817b0347cc224beace7c9f  ...   Drinks
# 28  4e45286d922ed454ab37c6d8  ...   Drinks
# 29  4c7024839375a09389120637  ...   Drinks
# 30  4b79e42ff964a520b3182fe3  ...   Drinks
# 31  4ede76b9b8f7fcd0450d5c2d  ...   Drinks
# 32  4e4477cbb61cac6fc7566a00  ...   Drinks
# 33  4cde2367825e721e4ecb6845  ...   Drinks
# 34  4bc8819292b376b04d7e513a  ...   Drinks
# 35  50b54771e4b06a856fd28603  ...   Drinks
# 36  4e6a31bb45ddadf2d05aae4d  ...   Drinks
# 37  4b058721f964a520698122e3  ...   Drinks
# 38  4d07a11cdc45a093e3bdf9c6  ...   Drinks
# 39  5a34375c588e361c21b3643e  ...   Drinks
# 40  4ce2a328ffcf3704c2ea2c82  ...   Drinks
# 41  4d176f75302da1cd06c3bb93  ...   Drinks
# 42  4d658d9e072a6ea8059afe4d  ...   Drinks
# 43  4f8c80ece4b0a95f96c70b7a  ...   Drinks
# 44  50e04638e4b0f6dd11ff1651  ...   Drinks
# 45  4eee4295f9ab8c5a0299e68f  ...   Drinks
# 46  52647763498e6bff66c4ad3f  ...   Drinks
# 47  56196633498e6d487ecf6fec  ...   Drinks
# 48  54e8cc11498ecf80c8a37cd7  ...   Drinks
# 49  4ec659ed4690116a8ab6144e  ...   Drinks
#
# [50 rows x 20 columns]

# %% [markdown]
# Collecting Museum data and adding related category column:

# %%
search_query = 'museu'
limit_places = 100
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, search_query, radius, limit_places)

results = requests.get(url).json()

museus = results['response']['venues']
df_museus = json_normalize(museus)

df_museus['category'] = 'Museu'
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead

# %%
print(df_museus.info())
print(df_museus.shape)
df_museus.head(100)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         50 non-null     object
#  1   name                       50 non-null     object
#  2   categories                 50 non-null     object
#  3   referralId                 50 non-null     object
#  4   hasPerk                    50 non-null     bool
#  5   location.address           45 non-null     object
#  6   location.lat               50 non-null     float64
#  7   location.lng               50 non-null     float64
#  8   location.labeledLatLngs    50 non-null     object
#  9   location.distance          50 non-null     int64
#  10  location.postalCode        41 non-null     object
#  11  location.cc                50 non-null     object
#  12  location.city              49 non-null     object
#  13  location.state             49 non-null     object
#  14  location.country           50 non-null     object
#  15  location.formattedAddress  49 non-null     object
#  16  location.crossStreet       7 non-null      object
#  17  location.neighborhood      3 non-null      object
#  18  venuePage.id               2 non-null      object
#  19  category                   50 non-null     object
# dtypes: bool(1), float64(2), int64(1), object(16)
# memory usage: 7.6+ KB
# None
# (50, 20)
#                           id  ... category
# 0   4cd6b75f89eb6dcb75e8301e  ...    Museu
# 1   4b058724f964a520ee8122e3  ...    Museu
# 2   4b058724f964a520f08122e3  ...    Museu
# 3   4dcbe46ed22d7ffe9d37b9e8  ...    Museu
# 4   516bfb45e4b0b4d66628e1f8  ...    Museu
# 5   4b058724f964a520fb8122e3  ...    Museu
# 6   57ffd84438fa38b857082ec3  ...    Museu
# 7   4ee0ebead3e38ddb2b2667f5  ...    Museu
# 8   56741ea6498e999035b89e4c  ...    Museu
# 9   4f046fac4901a1400b333a08  ...    Museu
# 10  4b058724f964a520f98122e3  ...    Museu
# 11  4eb6854a823131626fb46f9a  ...    Museu
# 12  4b9a4ae6f964a52015aa35e3  ...    Museu
# 13  4e19e123d1648b83483ffce7  ...    Museu
# 14  4b058724f964a520048222e3  ...    Museu
# 15  51b0e7f77dd2bc454dfb0315  ...    Museu
# 16  4ce434beb8df5481bc87b29b  ...    Museu
# 17  4ede93c80e612072e983e89b  ...    Museu
# 18  4db1ab245da32cf2df6154b4  ...    Museu
# 19  508921e6e4b06cb69f67a3a8  ...    Museu
# 20  4b058725f964a5200e8222e3  ...    Museu
# 21  4b058725f964a5200c8222e3  ...    Museu
# 22  4c8670d4d34ca1430dd74f80  ...    Museu
# 23  506199eae4b0eeba838c8516  ...    Museu
# 24  4d7068f6c7f8224b50f3affb  ...    Museu
# 25  4bf52ff2ed30b713b330f49a  ...    Museu
# 26  51daac82498e2622c1b15d1d  ...    Museu
# 27  52ebfb0e11d28ae5b1643598  ...    Museu
# 28  50b3c381e4b09a791eefef40  ...    Museu
# 29  51917bd8498eebc6a49fcba8  ...    Museu
# 30  55030858498e1c8a3ed6f36e  ...    Museu
# 31  4c8bc6595e38b1f7e5042bf9  ...    Museu
# 32  4f73736be4b0bfa7ff2d0a7a  ...    Museu
# 33  4e6284f5c65b2dc89fab9a17  ...    Museu
# 34  4db5a0fc0cb6729b6aa92d3e  ...    Museu
# 35  4e54f1b57d8b96cd0612f240  ...    Museu
# 36  503518cce4b0a2d03dc424b4  ...    Museu
# 37  509d5bc5e4b09f01847fd1c1  ...    Museu
# 38  524c1ca0498e72c6f9ea3ceb  ...    Museu
# 39  51e6eed3498ebfef46f479fd  ...    Museu
# 40  4c7c9e8720bb199c56932629  ...    Museu
# 41  4b058725f964a520058222e3  ...    Museu
# 42  4e567442c65be3cea46621b9  ...    Museu
# 43  59bb6f3cdb1d81620e2eec6d  ...    Museu
# 44  5dffadd9117a3c000856d357  ...    Museu
# 45  56054847498eb0f0608a0bcf  ...    Museu
# 46  5ba645b016ef670039c689e9  ...    Museu
# 47  50cd2ae4e4b06fef26ac9486  ...    Museu
# 48  58371f9c6b0cdb23941b7397  ...    Museu
# 49  4f5e09ece4b0b28dd640be6b  ...    Museu
#
# [50 rows x 20 columns]

# %% [markdown]
# Using pd.Concat to merge venues dataframes:

# %%
df_venues_concat = pd.concat([df_food, df_coffee, df_drinks, df_museus], ignore_index=True, sort=False)

# %%
print(df_venues_concat.info())
print(df_venues_concat.shape)
df_venues_concat.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         200 non-null    object
#  1   name                       200 non-null    object
#  2   categories                 200 non-null    object
#  3   referralId                 200 non-null    object
#  4   hasPerk                    200 non-null    bool
#  5   location.address           159 non-null    object
#  6   location.lat               200 non-null    float64
#  7   location.lng               200 non-null    float64
#  8   location.labeledLatLngs    200 non-null    object
#  9   location.distance          200 non-null    int64
#  10  location.postalCode        120 non-null    object
#  11  location.cc                200 non-null    object
#  12  location.city              174 non-null    object
#  13  location.state             175 non-null    object
#  14  location.country           200 non-null    object
#  15  location.formattedAddress  177 non-null    object
#  16  location.crossStreet       39 non-null     object
#  17  category                   200 non-null    object
#  18  location.neighborhood      6 non-null      object
#  19  venuePage.id               4 non-null      object
# dtypes: bool(1), float64(2), int64(1), object(16)
# memory usage: 30.0+ KB
# None
# (200, 20)
#                          id  ... venuePage.id
# 0  57e59302498e6a859d6dd2df  ...          NaN
# 1  56427127498e4309fc73811e  ...          NaN
# 2  5e5bf05498c49900087f5703  ...          NaN
# 3  5f5f6c9624ae6f671d9fe64b  ...          NaN
# 4  55d34ae5498e9a38dae27fb8  ...          NaN
#
# [5 rows x 20 columns]

# %% [markdown]
# Now Let's work on this dataframe to remove useless columns, rename the useful ones like we did with the hotel dataframe:

# %%
df_places = pd.DataFrame([df_venues_concat['name'],df_venues_concat['location.lat'],df_venues_concat['location.lng'],df_venues_concat['location.distance'],df_venues_concat['category']])
df_places = df_places.transpose()

df_places.rename(columns={'location.lat':'latitude','location.lng':'longitude','location.state':'state','location.distance':'distance'}, inplace=True)
df_places = df_places.astype({"distance":'int'})

# %%
print(df_places.info())
print(df_places.shape)
df_places
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   name       200 non-null    object
#  1   latitude   200 non-null    object
#  2   longitude  200 non-null    object
#  3   distance   200 non-null    int64
#  4   category   200 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 7.9+ KB
# None
# (200, 5)
#                                    name latitude longitude  distance category
# 0            Mr. Fit Fast Food Saudável   -22.91  -43.1712       728     Food
# 1                  Joe's Pub Food Truck -22.9266  -43.1766      2180     Food
# 2                       Vou Street Food -22.9147  -43.1664       491     Food
# 3                    Kitchen Asian Food -22.9203  -43.1705      1248     Food
# 4                 Mix Folhas Fresh Food -22.9051  -43.1738      1164     Food
# ..                                  ...      ...       ...       ...      ...
# 195                      Museu Calustre -22.9088  -43.1953      3201    Museu
# 196      Junta Local Museu da República  -22.926   -43.176      2086    Museu
# 197  Museu Janete Costa de Arte Popular -22.9037  -43.1281      3779    Museu
# 198       museu do desporto do exercito -22.9442  -43.1575      3789    Museu
# 199             Museu Antonio Parreiras -22.9018  -43.1261      4032    Museu
#
# [200 rows x 5 columns]

# %% [markdown]
# Let's plot again to check how things are going:

# %%
map_centro_analysis = folium.Map(location=[airport_lat, airport_lon],zoom_start=15)

for lat, lon, name in zip(df_places['latitude'],df_places['longitude'],df_places['name']):
    label = '{}'.format(name)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        fill=True,
        color='purple',
        fill_color='purple',
        fill_opacity=0.5
        ).add_to(map_centro_analysis)
map_centro_analysis
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_d38dc63c0c5d4960939bf9ecab3a4574%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_d38dc63c0c5d4960939bf9ecab3a4574%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_d38dc63c0c5d4960939bf9ecab3a4574%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_d38dc63c0c5d4960939bf9ecab3a4574%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B-22.91071875%2C%20-43.164178244974906%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2015%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_fa74526444cd4d85bd1b60628abeee4d%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20 ...

# %% [markdown]
# As we could see, for some reason the API is giving us results outside the stated radius which are not all that interesting for us, so we'll drop those entries from the database.

# %%
dropdistance = df_places[df_places['distance'] > 3000].index
df_places.drop(dropdistance, inplace=True)

# %%
df_places
# Out:
#                                            name latitude  ... distance  category
# 0                    Mr. Fit Fast Food Saudável   -22.91  ...      728      Food
# 1                          Joe's Pub Food Truck -22.9266  ...     2180      Food
# 2                               Vou Street Food -22.9147  ...      491      Food
# 3                            Kitchen Asian Food -22.9203  ...     1248      Food
# 4                         Mix Folhas Fresh Food -22.9051  ...     1164      Food
# ..                                          ...      ...  ...      ...       ...
# 190  Museu Histórico e Diplomático do Itamaraty -22.9039  ...     2652     Museu
# 191             Museu Casa de Benjamin Constant  -22.919  ...     2507     Museu
# 192                      Museu Light da Energia -22.9015  ...     2629     Museu
# 194                        Cine Museu Do Catete  -22.926  ...     2124     Museu
# 196              Junta Local Museu da República  -22.926  ...     2086     Museu
#
# [130 rows x 5 columns]

# %% [markdown]
# Finally, let's merge our venues and hotels dataframes:

# %%
df_centro = pd.concat([df_places, df_hoteis], ignore_index=True, sort=False)

# %%
print(df_centro.info())
print(df_centro.shape)
df_centro.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160 entries, 0 to 159
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   name       160 non-null    object
#  1   latitude   160 non-null    object
#  2   longitude  160 non-null    object
#  3   distance   160 non-null    object
#  4   category   160 non-null    object
# dtypes: object(5)
# memory usage: 6.4+ KB
# None
# (160, 5)
#                          name latitude longitude distance category
# 0  Mr. Fit Fast Food Saudável   -22.91  -43.1712      728     Food
# 1        Joe's Pub Food Truck -22.9266  -43.1766     2180     Food
# 2             Vou Street Food -22.9147  -43.1664      491     Food
# 3          Kitchen Asian Food -22.9203  -43.1705     1248     Food
# 4       Mix Folhas Fresh Food -22.9051  -43.1738     1164     Food

# %% [markdown]
# ## **4 - Using Silhouette and Elbow to find the best k**<a name="metrics"></a>

# %% [markdown]
# Now that we have our dataframes all set, let's now group our data points and try to find out the best k (the number of centroids) for our venues clusters:

# %% [markdown]
# We will use the Silhouette score and the Elbow Method to help us find the best number of centroids:

# %%
from sklearn.metrics import silhouette_score
sil = []
k_sil = range(2,10)
df_distance_clusters = df_centro.drop(['name','distance','category'],1)

for k in k_sil:
  kmeans = KMeans(n_clusters = k,random_state=0).fit(df_distance_clusters)
  labels = kmeans.labels_
  sil.append(silhouette_score(df_distance_clusters, labels, metric = 'euclidean'))

# %%
plt.plot(k_sil, sil, 'bx-')
plt.xlabel('k')
plt.ylabel('silhouette score')
plt.title('Silhouette for optimal k')
plt.show()

# %%
sqd = []
k = range(2,10)
for i in k:
  kmeans = KMeans(n_clusters=i).fit(df_distance_clusters)
  sqd.append(kmeans.inertia_)

# %%
plt.plot(k, sqd, 'bx-')
plt.xlabel('k')
plt.ylabel('Sum of Squared Distances')
plt.title('Elbow for optimal k')
plt.show()

# %% [markdown]
# According to the scores above, k=4 would be a good approach to our clustering problem. We will have 4 well defined centroid/clusters, so lets fit the model and plot again:

# %%
k=4
kmeans = KMeans(n_clusters = k,random_state=0).fit(df_distance_clusters)
kmeans.labels_
df_centro.insert(0, 'clusterlabels', kmeans.labels_)

# %%
print(df_centro.info())
print(df_centro.shape)
df_centro
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160 entries, 0 to 159
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   clusterlabels  160 non-null    int32
#  1   name           160 non-null    object
#  2   latitude       160 non-null    object
#  3   longitude      160 non-null    object
#  4   distance       160 non-null    object
#  5   category       160 non-null    object
# dtypes: int32(1), object(5)
# memory usage: 7.0+ KB
# None
# (160, 6)
#      clusterlabels                        name  ... distance category
# 0                1  Mr. Fit Fast Food Saudável  ...      728     Food
# 1                0        Joe's Pub Food Truck  ...     2180     Food
# 2                1             Vou Street Food  ...      491     Food
# 3                0          Kitchen Asian Food  ...     1248     Food
# 4                1       Mix Folhas Fresh Food  ...     1164     Food
# ..             ...                         ...  ...      ...      ...
# 155              2           ibis Budget Hotel  ...     1855    Hotel
# 156              0          Mengo Palace Hotel  ...     2283    Hotel
# 157              2            Fluminense Hotel  ...     2119    Hotel
# 158              2             HOTEL Champagne  ...     2752    Hotel
# 159              3                Center Hotel  ...     2079    Hotel
#
# [160 rows x 6 columns]

# %%
colors={0:'red',1:'blue',2:'green',3:'purple',4:'orange'}

map_centro_cluster = folium.Map(location=[airport_lat, airport_lon],zoom_start=15)

for lat, lon, clusters, name in zip(df_centro['latitude'],df_centro['longitude'],df_centro['clusterlabels'],df_centro['name']):
    label = '{}'.format(name)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        fill=True,
        color=colors[clusters],
        fill_color=colors[clusters],
        fill_opacity=0.5
        ).add_to(map_centro_cluster)

map_centro_cluster
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_67016d8d29cd4ed292809910cab34d38%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_67016d8d29cd4ed292809910cab34d38%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_67016d8d29cd4ed292809910cab34d38%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_67016d8d29cd4ed292809910cab34d38%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B-22.91071875%2C%20-43.164178244974906%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2015%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_96c8eb3cb07546beb7eeb1f4440eacbb%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20 ...

# %% [markdown]
# ## **5 - Clean visuals for our clusters & final mapping**<a name="visuals"></a>

# %% [markdown]
# We want this map to be easier to be more intuitive, and Font Awesome icons with Folium marker can help us with that. For that we'll need to make one more adjustment on our data. First we'll change the type of the column 'category' and then capture their codes:

# %%
df_centro = df_centro.astype({"category":'category'})
df_centro['category-id'] = df_centro['category'].cat.codes
df_centro = df_centro.astype({"category-id":'int'})

# %%
print(df_centro.info())
print(df_centro.shape)
df_centro.head(60)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160 entries, 0 to 159
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   clusterlabels  160 non-null    int32
#  1   name           160 non-null    object
#  2   latitude       160 non-null    object
#  3   longitude      160 non-null    object
#  4   distance       160 non-null    object
#  5   category       160 non-null    category
#  6   category-id    160 non-null    int64
# dtypes: category(1), int32(1), int64(1), object(4)
# memory usage: 7.4+ KB
# None
# (160, 7)
#     clusterlabels                               name  ... category category-id
# 0               1         Mr. Fit Fast Food Saudável  ...     Food           2
# 1               0               Joe's Pub Food Truck  ...     Food           2
# 2               1                    Vou Street Food  ...     Food           2
# 3               0                 Kitchen Asian Food  ...     Food           2
# 4               1              Mix Folhas Fresh Food  ...     Food           2
# 5               1                 Rildy Carioca Food  ...     Food           2
# 6               1                    Cogu Food Truck  ...     Food           2
# 7               1            Assima - Fast food CMRJ  ...     Food           2
# 8               1                  Farani Fresh Food  ...     Food           2
# 9               1      Marley's Coisinhas Food Truck  ...     Food           2
# 10              1        Marley's Cousine Food Truck  ...     Food           2
# 11              1   Barraca Da Chiquita - Food Truck  ...     Food           2
# 12              3                 UpGrade Food Truck  ...     Food           2
# 13              2                North American Food  ...     Food           2
# 14              3                 Verdano Fresh Food  ...     Food           2
# 15              2                 Rio Food Truck Bar  ...     Food           2
# 16              1              Hangar 11 Restaurante  ...     Food           2
# 17              0          Big Daddy's American Food  ...     Food           2
# 18              0                  Baguel Food Truck  ...     Food           2
# 19              3                  Nômade Food Truck  ...     Food           2
# 20              3             Zitti&Co. Comfort Food  ...     Food           2
# 21              3                  Biboca Food Truck  ...     Food           2
# 22              3                 Carango Food Truck  ...     Food           2
# 23              0                           Pet Food  ...     Food           2
# 24              3                 Belgo Food e Drink  ...     Food           2
# 25              3          Le Petit Paris Food Truck  ...     Food           2
# 26              3                         Baruk Food  ...     Food           2
# 27              2                   Prime Food Truck  ...     Food           2
# 28              1                   Baguel FoodTruck  ...     Food           2
# 29              1               Nobre Foods & Drinks  ...     Food           2
# 30              2                Gastrô Coffee Break  ...   Coffee           0
# 31              2                             Coffee  ...   Coffee           0
# 32              3                        Coffee Five  ...   Coffee           0
# 33              1                 Brasas Coffee Shop  ...   Coffee           0
# 34              1                  California Coffee  ...   Coffee           0
# 35              3                         DarkCoffee  ...   Coffee           0
# 36              1              Bario Coffee And More  ...   Coffee           0
# 37              0                         Coffee Bis  ...   Coffee           0
# 38              3                 Coffee Break GPLux  ...   Coffee           0
# 39              3                  California Coffee  ...   Coffee           0
# 40              0                        Coffee Shop  ...   Coffee           0
# 41              0       Coffee Shop Quartier Carioca  ...   Coffee           0
# 42              3                     Special Coffee  ...   Coffee           0
# 43              2                      Aussie Coffee  ...   Coffee           0
# 44              1                          Starbucks  ...   Coffee           0
# 45              0                  Lira Coffee House  ...   Coffee           0
# 46              1                  coffeemaker point  ...   Coffee           0
# 47              1                          Starbucks  ...   Coffee           0
# 48              3                          Starbucks  ...   Coffee           0
# 49              1           Bar e Restaurante 14 Bis  ...   Drinks           1
# 50              1                                Bar  ...   Drinks           1
# 51              1             Kris Restaurante e Bar  ...   Drinks           1
# 52              1  Carioca Maneiro Bar e Restaurante  ...   Drinks           1
# 53              1                       Bar do Elias  ...   Drinks           1
# 54              1         Bar e Restaurante Academia  ...   Drinks           1
# 55              1                Café e Bar Cortesia  ...   Drinks           1
# 56              1                Chopperia Super Bar  ...   Drinks           1
# 57              3            Bar e Restaurante Edeal  ...   Drinks           1
# 58              3                    Bar  Mercadores  ...   Drinks           1
# 59              1                           Lord Bar  ...   Drinks           1
#
# [60 rows x 7 columns]

# %%
icons={0:'fa-coffee', 1:'fa-glass', 2:'fa-cutlery', 3:'fa-h-square', 4:' fa-university'}

centro_marker = folium.Map(location=[airport_lat, airport_lon],zoom_start=15)

for latitude, longitude, name, clusters, category in zip(df_centro['latitude'],df_centro['longitude'],df_centro['name'], df_centro['clusterlabels'], df_centro['category-id']):
    label = '{}, Região {}'.format(name, clusters)
    folium.Marker(
        [latitude, longitude],
        popup=label,
        icon=folium.Icon(color=colors[clusters],icon=icons[category], prefix='fa')
        ).add_to(centro_marker)

centro_marker
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_8bf1026428454d54bdf1debb75f7a741%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_8bf1026428454d54bdf1debb75f7a741%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_8bf1026428454d54bdf1debb75f7a741%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_8bf1026428454d54bdf1debb75f7a741%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B-22.91071875%2C%20-43.164178244974906%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2015%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_5aab8e91258a44978cc1468f7f046de6%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20 ...

# %% [markdown]
# To make our final analysis easier, we can check how many different venues we have in each cluster, using GroupBy to create a new dataframe:

# %%
count_clusters = df_centro.groupby(['clusterlabels','category']).count()
count_clusters = count_clusters['category-id']
count_clusters = pd.DataFrame(count_clusters)
count_clusters.reset_index(inplace = True)
count_clusters = count_clusters.pivot_table(index = 'clusterlabels', columns ='category', values ='category-id')

# %%
count_clusters
# Out:
# category       Coffee  Drinks  Food  Hotel  Museu
# clusterlabels
# 0                   4       3     5     10      8
# 1                   6      13    13      8      7
# 2                   3      17     3      9     12
# 3                   6      12     9      3      9

# %%
count_clusters.plot(kind='bar', figsize=(10, 6))
plt.xlabel('Clusters') # add to x-label to the plot
#plt.ylabel('') # add y-label to the plot
plt.title('Venues by clusters') # add title to the plot
plt.xticks(rotation=0)

plt.show()

# %% [markdown]
# ## **6 - What can we understand from the data?**<a name="conclusion"></a>

# %% [markdown]
# Our analysis shows that, while we have some options all around the neighborhood, some of the venues really concentrate in a few areas, while other presents good oportunities for new businesses.

# %%
centro_marker
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_8bf1026428454d54bdf1debb75f7a741%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_8bf1026428454d54bdf1debb75f7a741%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_8bf1026428454d54bdf1debb75f7a741%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_8bf1026428454d54bdf1debb75f7a741%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B-22.91071875%2C%20-43.164178244974906%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2015%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_5aab8e91258a44978cc1468f7f046de6%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20 ...

# %% [markdown]
# - Zone 0 (red markers on the map), the nearest to the airport, is a well-balanced region, with good amount of different venues and activities, which could be an interesting option for a traveler who doesn't have a lot of time and wishes to visit a couple of interesting places on foot.
# - Zone 1 (blue markers on the map) is the less crowded overall, but maybe that's because its located on the edge of Rio's Centro, and closer to the Zona Sul (South Zone), where some of the most famous beaches and neighborhoods like Copacabana are located. It could be a great option for those who are willing to travel a bit far and enjoy more of the City.
# - Zone 2 (green markers on the map) has the most options of bars (17) and museums (12), while severely lacking on food (3) and coffee shop (3) options. This could mean a hotspot for tourists who would prefer a busy evening and lots of activities in the nigh life.
# - Zone 3 (purple markers on the map) is a well-balanced area for activities, with a bit of everything, but one may find the hotel choices in the area a bit restrictive, as there are only 3 options to choose from.
#
#
# Our clusters also could help a potential investor find good spots for opening new businesses. As an example, Zone 2, the one that has the most variety of museums and nightlife, could really use more options of restaurants or food trucks.

# %% [markdown]
# #### 6.1 - Conclusion
# The purpose of this project was to map venues around Rio de Janeiro's Centro and provide a general overview to tourists coming to the city, so they would be able to make well-informed choices regarding their stay and based on their personal interests. The data gathered could also be used to indicate hotspots with bigger demand for potential new businesses around the neighborhood. For further projects, we could implement a recommender system that would allow the user to choose, via a web interface their prefered spots and receive custom suggestions for hotels and interesting venues.
